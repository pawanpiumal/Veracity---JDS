# %%
import pandas as pd  
import json

# %%
df = pd.DataFrame()

# %%
start = 1
num = 10000

# %%
f = open('./dev.jsonl',encoding='utf-8')
lines = f.readlines()

# %%
if(len(lines)<num):
    num = len(lines)

# %%
jsonArray = []
for rowNumber in range(start-1,start-1+num):
    item = json.loads(lines[rowNumber])
    array = []
    for e in item['annotations']:
        if(e['short_answers'] != [] and e['short_answers'][0]['start_token'] != -1 and e['short_answers'][0]['end_token'] != -1):
            for token in e['short_answers']:
                stringArr = []
                for i in range(token['start_token'],token['end_token']):
                    stringArr.append(item['document_tokens'][i]['token'])
                array.append(" ".join(stringArr))
    newItem = {
        "document_title":item['document_title'],
        'question_text':item['question_text'],
        'yes_no_answer':list(map(lambda x: x['yes_no_answer'],item['annotations']))
    }
    for no in range(0,len(array)):
        newItem[f'short_answer{no+1}']= array[no]
    df2 = pd.DataFrame([newItem])
    df = pd.concat([df, df2])
    # print(newItem)

# %%
# df

# %%
df.to_csv(f'file{start}-{start+num-1}.csv')

# %%
df.columns
# Out:
# Index(['document_title', 'question_text', 'yes_no_answer', 'short_answer1',
#        'short_answer2', 'short_answer3', 'short_answer4', 'short_answer5',
#        'short_answer6', 'short_answer7', 'short_answer8', 'short_answer9',
#        'short_answer10', 'short_answer11', 'short_answer12', 'short_answer13',
#        'short_answer14', 'short_answer15', 'short_answer16', 'short_answer17',
#        'short_answer18', 'short_answer19', 'short_answer20', 'short_answer21',
#        'short_answer22', 'short_answer23', 'short_answer24', 'short_answer25',
#        'short_answer26', 'short_answer27', 'short_answer28', 'short_answer29',
#        'short_answer30', 'short_answer31', 'short_answer32', 'short_answer33',
#        'short_answer34', 'short_answer35', 'short_answer36', 'short_answer37',
#        'short_answer38', 'short_answer39', 'short_answer40', 'short_answer41',
#        'short_answer42', 'short_answer43', 'short_answer44', 'short_answer45',
#        'short_answer46', 'short_answer47', 'short_answer48', 'short_answer49',
#        'short_answer50'],
#       dtype='object')

# %%
df.head()
# Out:
#                   document_title  \
# 0                 Therefore sign
# 0     Watchman (law enforcement)
# 0  Photograph (Ringo Starr song)
# 0    Super Bowl 50 halftime show
# 0                    Matt Lanter
#
#                                        question_text  \
# 0                    what do the 3 dots mean in math
# 0            when was the writ watch invented by who
# 0       who wrote the song photograph by ringo starr
# 0  who is playing the halftime show at super bowl...
# 0        star wars the clone wars anakin voice actor
#
#                     yes_no_answer  \
# 0  [NONE, NONE, NONE, NONE, NONE]
# 0  [NONE, NONE, NONE, NONE, NONE]
# 0  [NONE, NONE, NONE, NONE, NONE]
# 0  [NONE, NONE, NONE, NONE, NONE]
# 0  [NONE, NONE, NONE, NONE, NONE]
#
#                                        short_answer1  \
# 0  the therefore sign ( ∴ ) is generally used bef...
# 0                                                NaN
# 0                                        Ringo Starr
# 0  Coldplay with special guest performers Beyoncé...
# 0               Matthew MacKendree `` Matt '' Lanter
#
#                           short_answer2  \
# 0                    the therefore sign
# 0                                   NaN
# 0                       George Harrison
# 0                              Coldplay
# 0  Matthew MacKendree `` Matt '' Lanter
#
#                                        short_answer3    short_answer4  \
# 0  a logical consequence , such as the conclusion...   therefore sign
# 0                                                NaN              NaN
# 0                                    Richard Starkey  George Harrison
# 0                                            Beyoncé       Bruno Mars
# 0               Matthew MacKendree `` Matt '' Lanter              NaN
#
#                                        short_answer5    short_answer6  \
# 0                                                NaN              NaN
# 0                                                NaN              NaN
# 0                                        Ringo Starr  George Harrison
# 0  British rock group Coldplay with special guest...         Coldplay
# 0                                                NaN              NaN
#
#   short_answer7  ... short_answer41 short_answer42 short_answer43  \
# 0           NaN  ...            NaN            NaN            NaN
# 0           NaN  ...            NaN            NaN            NaN
# 0           NaN  ...            NaN            NaN            NaN
# 0       Beyoncé  ...            NaN            NaN            NaN
# 0           NaN  ...            NaN            NaN            NaN
#
#   short_answer44 short_answer45 short_answer46 short_answer47 short_answer48  \
# 0            NaN            NaN            NaN            NaN            NaN
# 0            NaN            NaN            NaN            NaN            NaN
# 0            NaN            NaN            NaN            NaN            NaN
# 0            NaN            NaN            NaN            NaN            NaN
# 0            NaN            NaN            NaN            NaN            NaN
#
#   short_answer49 short_answer50
# 0            NaN            NaN
# 0            NaN            NaN
# 0            NaN            NaN
# 0            NaN            NaN
# 0            NaN            NaN
#
# [5 rows x 53 columns]
